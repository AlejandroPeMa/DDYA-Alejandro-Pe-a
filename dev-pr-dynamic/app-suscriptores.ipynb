# %% [markdown]
# ## Problema - Organización y búsqueda de productos en una tienda
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
# @title Ingrese datos
nombre_estudiante = "Alejandro Peña Martinez" # @param {"type":"string"}
carnet = 1000113821 # @param {"type":"integer"}

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**
# Una plataforma de streaming está analizando el crecimiento de nuevos suscriptores.
# Se ha observado que el número de nuevos suscriptores en el mes n sigue el siguiente
# comportamiento:
# • En el mes 0 se registraron 0 nuevos usuarios.
# • En el mes 1 se registró 1 nuevo usuario.
# • A partir del mes 2, el número de nuevos usuarios es igual a la suma de los nuevos usuarios de
# los dos meses anteriores, debido al efecto combinado de referidos del mes anterior y
# recomendaciones acumuladas del mes previo.
# Relación de recurrencia:
#
# T(n) = 0 si n = 0
#
# T(n) = 1 si n = 1
#
# T(n) = T(n-1) + T(n-2) si n ≥ 2
#
# Determinar con memoización cuántos nuevos suscriptores habrá en el mes n.

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**
#
# Lista requerimientos **funcionales** y **no funcionales**.
#
# ## Requerimientos funcionales:
#
#
# *   El sistema debe calcular el numero de suscriptores T(n) para cualquier mes "n" ingresado.
# *   El sistema debe calcular T(n) como la suma de T(n-1) y T(n-2) para eso n tendra que ser mayor o igual que 2 n>=2.
# *   El sistema debido al requerimiento anterior debe retornar 0 cuando n=0 y 1 cuando n=1.
# *   El sistema debe almacenar (memoizar) los resultados ya calculados y asi ser reutilizados.
# *   Para todos los requerimientos anteriores el sistema debe validar que n no sea negativo y aparte de eso sea un numero entero ya que se manejara por meses "n".
#
# ## Requerimientos no funcionales:
#
#
# *   El resultado o solucion debe tener complejidad O(n) gracias a la memoización.
# *   El sistema debe ser probado para obtener los mejores resultados.
# *   El codigo debe seguir buenas practicas en python.
# *

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**
#
# ## Historia de usuario 1:
# Como analista de plataformas, quiero calcular el numero de nuevos suscriptores de un mes especifico, para poder proyectar el crecimiento de nuevos suscriptores de un mes "n" especifico.
#
# Criterio de aceptacion 1: Para n=0, el sistema mostrara 0.
#
# Criterio de aceptacion 2: Para n=1, el sistema mostrar 1.
#
# ## Historia de usuario 2:
# Como analista de la plataforma quiero que el calculo de un mes grande sea rapido y asi no esperar demasiado tiempo.
#
# Criterio de aceptacion 1: Para n=30, el resultado se obtendra en menos de un segundo.
#
# Criterio de aceptacion 2: El algoritmo no recalcula el mismo subproblema dos veces.
#
#
# ##Historia de usuario 3:
# Como desarrollador quiero que la funcion valide las entradas para evitar errores de datos.
#
# Criterio de aceptacion 1: Si n es negativo, el sistema lanza un error.
#
# Criterio de aceptacion 2: Si n no es entero, el sistema lanza un error.

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 5) Análisis de complejidad **[15 pts]**
# Incluye:
# - Justificación
# - Función T[n]
# - Mejor y peor caso con gráfica
#
# ## Justificación:
# La version recursiva sin memoizacion de T(n)=T(n-1) + T(n-2) recalcula los mismos subproblemas una y otra vez. Lo que produce una complejidad temporal O(2^n) ese seria nuestro peor caso.
#
# Con memoizacion cada valor de n entre 0 y N se calcula una unica vez y asi no tener que volver hacerlo, si el usuario vuelve a ingresar el mismo n que ingreso antes se resuelve ingresando a memo. Como hay N+1 subproblemas distintos y cada uno se calcula en tiempo constante es decir por medio de una suma, la complejidad es 0(n). la complejidad espacial tambien es O(n) tanto por la tabla de memoizacion y tambien por la recursión.
#
# ## Funcion T(n):
#
# T(n)={ 0 si n=0, 1 si n=1, T(n-1)+T(n-2) si n>=2}
#
# ## Mejor y peor caso:
#
#
# *   Mejor caso: n=0 o n=1 el algoritmo retorna inmediatamente y tambien si n ha sido calculado antes, con complejidad O(1).
#
# *   Peor Caso: n grande y sin ningun dato en memo. el algoritmo debe resolver n+1 subproblemas antes de llegar al resultado final con complejidad O(n) gracias a la memoización.
#
# ## Grafica
# Hecha en excel
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 6) Código funcional **[15 pts]**
# Incluye tu implementación completa.
#
# No pegues código incompleto; debe ser ejecutable.

# %%
def suscriptores(n, memo=None):
   if not isinstance(n, int) or n < 0:
       raise ValueError("n debe ser un entero no negativo")
   if memo is None:
       memo = {}
   if n == 0:
       return 0
   if n == 1:
       return 1
   if n in memo:
       return memo[n]
   memo[n] = suscriptores(n - 1, memo) + suscriptores(n - 2, memo)
   return memo[n]

n = int(input("Ingrese el mes n: "))
print(f"Nuevos suscriptores en el mes {n}: {suscriptores(n)}")
# Out:
# Ingrese el mes n: 80
# Nuevos suscriptores en el mes 80: 23416728348467685

# %% [markdown]
# ## 7) Tests aplicados **[15 pts]**

# %%
# (Opcional) Ejemplo de asserts (ajusta a tu código):
# assert funcion(0) == 0
# assert funcion(1) == 1
# assert funcion(6) == 8

assert suscriptores(0) == 0
assert suscriptores(1) == 1
assert suscriptores(2) == 1
assert suscriptores(3) == 2
assert suscriptores(6) == 8
assert suscriptores(10) == 55
try:
   suscriptores(-1)
   assert False
except ValueError:
   pass
try:
   suscriptores(2.5)
   assert False
except ValueError:
   pass
print("Todas las pruebas estan correctas")
# Out:
# Todas las pruebas estan correctas
